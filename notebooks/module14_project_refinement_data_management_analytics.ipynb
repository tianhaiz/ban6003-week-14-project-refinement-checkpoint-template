# %% [markdown]
# # Module 14 Guided Lab: Final Project Refinement
#
# ## Data Management Story + Analytics Story
#
# **BAN 6003: Data Management and Analytics Integration**
#
# This module is about final project refinement. The final project should not be only a model report. At least half of the project should explain the **data management workflow** that made the analysis possible.
#
# A strong final project has two connected parts:
#
# 1. **Data management story:** how raw data became a trustworthy ABT.
# 2. **Analytics story:** what the model or analysis found, what it means, and how it should be used responsibly.
#
# Use this notebook as a template for revising your final project report and presentation.

# %% [markdown]
# ## Lab Learning Goals
#
# By the end of this lab, you should be able to:
#
# 1. Organize the final report around both data management and analytics.
# 2. Summarize profiling, cleaning, transformation, integration, and ABT construction.
# 3. Explain final ABT checks and documentation.
# 4. Interpret model or analytical results in business language.
# 5. State limitations, ethics, bias, fairness, and responsible-use concerns.
# 6. Connect results to cautious business recommendations.
# 7. Draft a final presentation storyline that gives enough space to the data workflow.

# %% [markdown]
# # 1. Recommended Final Project Balance
#
# Your final project should roughly balance these two areas:
#
# ## Part A: Data Management and ABT Preparation
#
# This should include:
#
# - business problem and data sources
# - data profiling
# - cleaning decisions
# - transformation decisions
# - integration or merge logic
# - ABT unit of analysis
# - data dictionary
# - validation checks
# - remaining data limitations
#
# ## Part B: Analytics, Interpretation, and Recommendation
#
# This should include:
#
# - target variable or analytical outcome
# - model or method
# - results and metrics
# - interpretation in business language
# - limitations
# - ethics and responsible use
# - recommendation and next steps
#
# The exact balance can vary, but do not let the model section erase the data management work.

# %% [markdown]
# ### Your Turn 1
#
# Write 3–5 sentences explaining how your final project will balance data management and analytics.
#
# Mention at least two data management steps and one analytics step.

# %% [markdown]
# **Your answer:**
# Type your answer here.

# %% [markdown]
# # 2. Executive Summary
#
# The executive summary should briefly mention both the data workflow and the analytical result.
#
# A weak summary only says:
#
# > I built a model and got 82% accuracy.
#
# A stronger summary says:
#
# > I profiled, cleaned, transformed, and integrated the data into a one-row-per-customer ABT, documented the key variables, and applied a classification model to identify customers with higher churn risk. The model may support screening, but results should be interpreted cautiously because of missing data and limited validation.

# %% [markdown]
# ### Executive Summary Template
#
# Complete the template:
#
# This project analyzes **[business problem]** using **[data source]**. I prepared the data by **[profiling/cleaning/transformation/integration steps]** and created an ABT where one row represents **[unit of analysis]**. I then applied **[model or analytical method]** to study **[target or outcome]**. The main finding is **[key result]**. This result can support **[business use]**, but it should be interpreted cautiously because **[main limitation or ethical concern]**.

# %% [markdown]
# ### Your Turn 2
#
# Draft your executive summary.

# %% [markdown]
# **Draft executive summary:**
# Type your answer here.

# %% [markdown]
# # 3. Business Problem and Data Sources
#
# Before describing the model, clearly explain the business problem and the data.
#
# Your reader should understand:
#
# - what decision or process the project supports
# - who would use the results
# - what data sources were used
# - what each raw dataset originally represented
# - why the data needed preparation

# %% [markdown]
# ### Your Turn 3
#
# Draft this section for your project.

# %% [markdown]
# **Business problem:**
# Type your answer here.
#
# **Data sources:**
# Type your answer here.
#
# **Why preparation was needed:**
# Type your answer here.

# %% [markdown]
# # 4. Data Profiling Summary
#
# Your final project should summarize what you learned when you first inspected the data.
#
# Include findings such as:
#
# - row and column counts
# - important data types
# - missing values
# - duplicate records or duplicate keys
# - suspicious or impossible values
# - categorical inconsistencies
# - columns that needed cleaning or transformation
#
# Do not include every profiling output. Summarize the important findings.

# %% [markdown]
# ### Example Profiling Summary
#
# The original dataset contained 50,000 transaction rows and 18 columns. Initial profiling showed missing values in customer age and income, duplicate customer IDs in the customer lookup table, and inconsistent category labels in the region field. Several date columns were stored as text and required conversion before analysis.

# %% [markdown]
# ### Your Turn 4
#
# Write your data profiling summary.

# %% [markdown]
# **Data profiling summary:**
# Type your answer here.

# %% [markdown]
# # 5. Cleaning and Transformation Summary
#
# This section should explain the main choices you made to make the data usable.
#
# Discuss:
#
# - missing value handling
# - duplicate handling
# - data type conversion
# - text or categorical standardization
# - derived variables
# - filtering or subsetting
# - reshaping or aggregation, if used
#
# Focus on decisions and reasons, not just function names.

# %% [markdown]
# ### Example Cleaning and Transformation Summary
#
# Missing rows in the target variable were removed because they could not be used for supervised modeling. Date fields were converted from text to datetime format. Region values were standardized by trimming extra spaces and converting labels to a consistent format. A new variable, customer_tenure_months, was created to measure customer history. Transaction-level data was aggregated to customer-level because the final ABT used one row per customer.

# %% [markdown]
# ### Your Turn 5
#
# Write your cleaning and transformation summary.

# %% [markdown]
# **Cleaning and transformation summary:**
# Type your answer here.

# %% [markdown]
# # 6. Integration and ABT Construction Summary
#
# This is one of the most important parts of the final project.
#
# Explain:
#
# - what tables or files were combined
# - what keys were used
# - what type of join or merge was used
# - whether aggregation was needed before joining
# - what one row means in the final ABT
# - what key columns define one row
# - what checks confirmed the ABT structure

# %% [markdown]
# ### Example ABT Construction Summary
#
# The final ABT was built at the customer level, with one row per customer. Transaction records were first aggregated to customer level using total spend, transaction count, and average transaction value. The aggregated transaction table was then left joined to the customer table using customer_id. Row counts were checked before and after the merge, and customer_id was checked for duplicates to confirm the one-row-per-customer structure.

# %% [markdown]
# ### Your Turn 6
#
# Write your integration and ABT construction summary.

# %% [markdown]
# **Integration and ABT construction summary:**
# Type your answer here.
#
# **Unit of analysis:**
# Type your answer here.
#
# **Key columns:**
# Type your answer here.

# %% [markdown]
# # 7. Data Dictionary and ABT Documentation
#
# Your final report should include or link to a data dictionary.
#
# At minimum, the data dictionary should include:
#
# - column name
# - data type
# - description
# - source
# - transformation or derivation
# - notes or concerns
#
# You do not need to show the full data dictionary in presentation slides, but you should summarize that it exists and explain the most important variables.

# %%
# Optional template for a project data dictionary.
# Replace the example rows with your own ABT columns.

data_dictionary_template = {
    "column_name": ["customer_id", "total_spend", "churn_flag"],
    "data_type": ["string", "numeric", "binary"],
    "description": [
        "Unique customer identifier",
        "Total customer spending during the observation period",
        "Target variable indicating whether the customer churned"
    ],
    "source": ["customer table", "transaction table", "customer status field"],
    "transformation_or_derivation": [
        "Original key field",
        "Aggregated from transaction-level records",
        "Recoded from customer status"
    ],
    "notes_or_concerns": [
        "Should be unique in final ABT",
        "May be affected by missing transaction records",
        "Definition depends on churn window"
    ]
}

import pandas as pd
pd.DataFrame(data_dictionary_template)

# %% [markdown]
# ### Your Turn 7
#
# Identify three columns from your ABT that need especially clear documentation.
#
# For each one, explain why it is important.

# %% [markdown]
# **Column 1:**
# Type your answer here.
#
# **Column 2:**
# Type your answer here.
#
# **Column 3:**
# Type your answer here.

# %% [markdown]
# # 8. Final ABT Checks
#
# Before analytics, summarize the final checks you ran.
#
# Include checks such as:
#
# - duplicate entity rows
# - missing values
# - impossible values
# - target variable issues
# - class balance for classification
# - train/test readiness
# - leakage risk
#
# This section should show that the ABT is reasonably ready for analysis.

# %% [markdown]
# ### Your Turn 8
#
# Write your final ABT checks summary.

# %% [markdown]
# **Final ABT checks summary:**
# Type your answer here.

# %% [markdown]
# # 9. Modeling or Analytical Method
#
# Now move into the analytics part.
#
# Explain:
#
# - whether your task is regression, classification, or descriptive analysis
# - what the target variable is, if applicable
# - what features or inputs were used
# - what method or model was applied
# - why that method is appropriate

# %%
# Optional example result table.
# Replace this with your own results.

model_results_example = pd.DataFrame({
    "model": ["Linear Regression", "Logistic Regression", "Decision Tree"],
    "main_metric": ["MAE", "Accuracy", "Recall"],
    "value": [12.4, 0.82, 0.61],
    "plain_language_meaning": [
        "Predictions were off by about 12.4 units on average.",
        "The model correctly classified about 82% of test cases.",
        "The model caught about 61% of actual positive cases."
    ]
})

model_results_example

# %% [markdown]
# ### Your Turn 9
#
# Write your modeling or analytical method explanation.

# %% [markdown]
# **Model/method explanation:**
# Type your answer here.

# %% [markdown]
# # 10. Results and Business Interpretation
#
# This section should translate output into meaning.
#
# Do not only list metrics. Explain what they mean for the business question.
#
# Use careful language:
#
# - "The model suggests..."
# - "The result is consistent with..."
# - "This may support..."
# - "This does not prove..."
# - "One limitation is..."

# %% [markdown]
# ### Your Turn 10
#
# Write one paragraph interpreting your results in business language.

# %% [markdown]
# **Business interpretation paragraph:**
# Type your answer here.

# %% [markdown]
# # 11. Limitations
#
# Your limitations section should cover both data management limitations and analytics limitations.
#
# ## Data management limitations
#
# Examples:
#
# - missing values
# - imperfect joins
# - recoding assumptions
# - limited time period
# - incomplete data sources
# - target variable definition issues
#
# ## Analytics limitations
#
# Examples:
#
# - simple model
# - limited features
# - no external validation
# - possible leakage
# - correlation, not causation
# - uncertain generalization

# %% [markdown]
# ### Your Turn 11
#
# Write a limitations paragraph that includes both data limitations and model/analysis limitations.

# %% [markdown]
# **Limitations paragraph:**
# Type your answer here.

# %% [markdown]
# # 12. Ethics, Bias, Fairness, and Responsible Use
#
# Ethics should connect to both the data workflow and the model output.
#
# Discuss:
#
# - sensitive fields or privacy concerns
# - whether data is representative
# - whether missingness or recoding may affect groups differently
# - who is affected by the recommendation
# - what happens if the model is wrong
# - whether human review is needed
# - what monitoring would be needed before deployment

# %% [markdown]
# ### Your Turn 12
#
# Write 4–6 sentences about ethics, bias, fairness, or responsible use in your project.

# %% [markdown]
# **Ethics and responsible use discussion:**
# Type your answer here.

# %% [markdown]
# # 13. Business Recommendations
#
# A strong recommendation should connect to:
#
# 1. the business problem
# 2. the prepared data and ABT
# 3. the model or analysis result
# 4. the limitations and responsible-use concerns
#
# Avoid recommendations that are too broad or unsupported.

# %% [markdown]
# ### Recommendation Template
#
# Based on **[finding]**, I recommend **[specific action]** for **[business user or process]**. This recommendation should be used **[carefully / as a screening tool / with human review / after further validation]** because **[limitation or risk]**.

# %% [markdown]
# ### Your Turn 13
#
# Write two project recommendations.

# %% [markdown]
# **Recommendation 1:**
# Type your answer here.
#
# **Recommendation 2:**
# Type your answer here.

# %% [markdown]
# # 14. Final Presentation Storyline
#
# Your presentation should give enough space to data management.
#
# A suggested balance:
#
# ## First half: Data management story
#
# 1. Business problem
# 2. Data sources
# 3. Data profiling findings
# 4. Cleaning and transformation
# 5. Integration and ABT construction
# 6. Final ABT checks and documentation
#
# ## Second half: Analytics story
#
# 7. Model or analytical method
# 8. Results and interpretation
# 9. Limitations, ethics, and responsible use
# 10. Recommendations and next steps

# %% [markdown]
# ### Your Turn 14
#
# Draft your final presentation storyline using 8–10 bullets.

# %% [markdown]
# **Presentation storyline:**
# Type your answer here.

# %% [markdown]
# # 15. Final Project Readiness Checklist
#
# ## Data management readiness
#
# - [ ] Business problem is clear.
# - [ ] Data sources are described.
# - [ ] Data profiling findings are summarized.
# - [ ] Cleaning decisions are explained.
# - [ ] Transformation decisions are explained.
# - [ ] Integration or merge logic is explained.
# - [ ] ABT unit of analysis is clear.
# - [ ] Key columns are identified.
# - [ ] Data dictionary is included or linked.
# - [ ] Final ABT checks are summarized.
#
# ## Analytics readiness
#
# - [ ] Target variable or analytical outcome is clear.
# - [ ] Model or method is appropriate.
# - [ ] Results are interpreted in business language.
# - [ ] Metrics are explained.
# - [ ] Limitations are included.
# - [ ] Ethics and responsible use are discussed.
# - [ ] Recommendations are specific and cautious.
#
# ## Submission readiness
#
# - [ ] GitHub repository is organized.
# - [ ] Final notebook/report is complete.
# - [ ] ABT and documentation files are included or accessible.
# - [ ] Presentation follows a clear storyline.
# - [ ] Final files are committed and pushed.

# %% [markdown]
# # 16. Final Reflection
#
# Write 5–7 sentences answering:
#
# 1. Which part of your project is stronger right now: data management or analytics?
# 2. What data management explanation still needs improvement?
# 3. What model or result explanation still needs improvement?
# 4. What limitation or ethical issue must be included?
# 5. What are your next two revision steps?

# %% [markdown]
# **Final reflection:**
# Type your answer here.

# %% [markdown]
# # 17. Save Your Work
#
# Before submitting this checkpoint:
#
# 1. Save the notebook.
# 2. Complete the draft sections.
# 3. Commit and push your work to GitHub.
#
# Suggested commands:
#
# ```bash
# git add .
# git commit -m "Revise Module 14 final project refinement"
# git push
# ```
